# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 72
plt.figure(figsize=(8, 6))

import numpy as np

# %%
agents_win_rates = np.load('output/agents_win_rates.npy')
agents_cumulative_rewards = np.load('output/agents_cumulative_rewards.npy')

for i in range(agents_cumulative_rewards.shape[0]):
    plt.plot(agents_cumulative_rewards[i], label=f'Agent {i+1}')

plt.title('DQN Agent Cumulative Rewards Over Time')
plt.xlabel('Episodes')
plt.ylabel('Cumulative Rewards')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_balance = np.load('../output/maybe_working/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_bet_sizes = np.load('output/agents_bet_sizes.npy')
print(len(agents_bet_sizes[0]))

plt.scatter(range(len(agents_bet_sizes[0])), agents_bet_sizes[0])
# for i in range(agents_bet_sizes.shape[0]):
#     plt.scatter(i, agents_bet_sizes[i], label=f'Agent {i+1}')

plt.title('DQN Agent Bet Size Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Bet Size')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 4000

# %%
agents_bet_sizes = np.load('output/agents_bet_sizes.npy')
print(len(agents_bet_sizes[0]))

plt.scatter(range(len(agents_bet_sizes[0])), agents_bet_sizes[0])
# for i in range(agents_bet_sizes.shape[0]):
#     plt.scatter(i, agents_bet_sizes[i], label=f'Agent {i+1}')

plt.title('DQN Agent Bet Size Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Bet Size')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 40000

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
agents_bet_sizes = np.load('output/agents_bet_sizes.npy')
print(len(agents_bet_sizes[0]))

plt.scatter(range(len(agents_bet_sizes[0])), agents_bet_sizes[0])
# for i in range(agents_bet_sizes.shape[0]):
#     plt.scatter(i, agents_bet_sizes[i], label=f'Agent {i+1}')

plt.title('DQN Agent Bet Size Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Bet Size')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# 100000000
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
agents_balance = np.load('output/agents_balance.npy')

for i in range(agents_balance.shape[0]):
    plt.plot(agents_balance[i], label=f'Agent {i+1}')

plt.title('DQN Agent Balance Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Balance')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 agents_balance = np.load('output/agents_balance.npy')
#       3 for i in range(agents_balance.shape[0]):
#       4     plt.plot(agents_balance[i], label=f'Agent {i+1}')
#
# NameError: name 'np' is not defined

# %%
agents_bet_sizes = np.load('output/agents_bet_sizes.npy')
print(len(agents_bet_sizes[0]))

plt.scatter(range(len(agents_bet_sizes[0])), agents_bet_sizes[0])
# for i in range(agents_bet_sizes.shape[0]):
#     plt.scatter(i, agents_bet_sizes[i], label=f'Agent {i+1}')

plt.title('DQN Agent Bet Size Over Time')
plt.xlabel('Episodes')
plt.ylabel('Agent Bet Size')
plt.grid(True)
plt.show()
# Out:
# 100000
